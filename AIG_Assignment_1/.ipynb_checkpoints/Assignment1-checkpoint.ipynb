# %%
using Pkg

# %%
Pkg.activate("AIG_Assignment_1")
# Out:
#  Activating new environment at `C:\Users\Gladwell\Documents\GitHub\AIG\AIG_Assignment_1\AIG_Assignment_1\Project.toml`

# %%
Pkg.add("DataFrames")
Pkg.add("CSV")
# Out:
#    Updating registry at `C:\Users\Gladwell\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %>                                 ]  15.5 % [===========================>             ]  66.5 % %3 %
#   Resolving package versions...

# %%
using CSV
using DataFrames
